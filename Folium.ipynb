# %%
import os
try:
    import folium
except:
    os.system("pip install folium")

# %%
import folium

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("zillow_forrent_queens_college.csv")
df['json_data'] = df['json_data'].astype(str)
df.head()
# Out:
#                                            json_data  \
# 0  {"@type":"SingleFamilyResidence","@context":"h...
# 1  {"@type":"SingleFamilyResidence","@context":"h...
# 2                                                nan
# 3                                                nan
# 4  {"@type":"SingleFamilyResidence","@context":"h...
#
#                                  list-card-link href  \
# 0  https://www.zillow.com/homedetails/13225-60th-...
# 1  https://www.zillow.com/homedetails/Pidgeon-Mea...
# 2  https://www.zillow.com/b/7311-153rd-St-Flushin...
# 3  https://www.zillow.com/b/14741-75th-Ave-Flushi...
# 4  https://www.zillow.com/homedetails/75th-Avenue...
#
#                                   list-card-addr      list-card-type  \
# 0         13225 60th Ave # 2, Flushing, NY 11355  Apartment for rent
# 1          Pidgeon Meadow Rd, Flushing, NY 11365  Apartment for rent
# 2                    7311 153rd St, Flushing, NY            For Rent
# 3                   14741 75th Ave, Flushing, NY            For Rent
# 4  75th Avenue Flushing Ny #, Flushing, NY 11367  Apartment for rent
#
#   list-card-price list-card-details list-card-label list-card-details 2  \
# 0       $2,200/mo                 3             bds                   2
# 1       $1,100/mo                 1              bd                   1
# 2             NaN           $1,800+            1 bd              $2,000
# 3             NaN           $1,800+            1 bd              $2,000
# 4       $1,400/mo            Studio              ba                   1
#
#   list-card-label 2 list-card-details 3 list-card-label 3  \
# 0                ba                  --              sqft
# 1                ba                  --              sqft
# 2             2 bds                 NaN               NaN
# 3             2 bds                 NaN               NaN
# 4              sqft                 350               NaN
#
#   list-card-variable-text                                 list-card-link src  \
# 0           2 minutes ago  https://photos.zillowstatic.com/p_e/ISzvm21bb7...
# 1             2 hours ago  https://photos.zillowstatic.com/p_e/ISzjps5q4i...
# 2       Updated yesterday  https://photos.zillowstatic.com/p_e/ISqlx5k0ff...
# 3             17 days ago  https://photos.zillowstatic.com/p_e/ISfoz7pt8a...
# 4            10 hours ago  https://photos.zillowstatic.com/p_e/IS2rl9jduo...
#
#   list-card-save-content list-card-truncate
# 0         Save this home                NaN
# 1         Save this home         C's Realty
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4         Save this home       Realty Depot

# %%
df = df[df['json_data'] != 'nan']
df.head()
# Out:
#                                            json_data  \
# 0  {"@type":"SingleFamilyResidence","@context":"h...
# 1  {"@type":"SingleFamilyResidence","@context":"h...
# 4  {"@type":"SingleFamilyResidence","@context":"h...
# 6  {"@type":"SingleFamilyResidence","@context":"h...
# 7  {"@type":"SingleFamilyResidence","@context":"h...
#
#                                  list-card-link href  \
# 0  https://www.zillow.com/homedetails/13225-60th-...
# 1  https://www.zillow.com/homedetails/Pidgeon-Mea...
# 4  https://www.zillow.com/homedetails/75th-Avenue...
# 6  https://www.zillow.com/homedetails/58th-Ave-Fl...
# 7  https://www.zillow.com/homedetails/5621-Van-Cl...
#
#                                   list-card-addr      list-card-type  \
# 0         13225 60th Ave # 2, Flushing, NY 11355  Apartment for rent
# 1          Pidgeon Meadow Rd, Flushing, NY 11365  Apartment for rent
# 4  75th Avenue Flushing Ny #, Flushing, NY 11367  Apartment for rent
# 6                   58th Ave, Flushing, NY 11355  Apartment for rent
# 7          5621 Van Cleef St, Flushing, NY 11368  Apartment for rent
#
#   list-card-price list-card-details list-card-label list-card-details 2  \
# 0       $2,200/mo                 3             bds                   2
# 1       $1,100/mo                 1              bd                   1
# 4       $1,400/mo            Studio              ba                   1
# 6       $2,300/mo                 3             bds                   2
# 7       $2,500/mo                 3             bds                   1
#
#   list-card-label 2 list-card-details 3 list-card-label 3  \
# 0                ba                  --              sqft
# 1                ba                  --              sqft
# 4              sqft                 350               NaN
# 6                ba               1,200              sqft
# 7                ba               3,078              sqft
#
#   list-card-variable-text                                 list-card-link src  \
# 0           2 minutes ago  https://photos.zillowstatic.com/p_e/ISzvm21bb7...
# 1             2 hours ago  https://photos.zillowstatic.com/p_e/ISzjps5q4i...
# 4            10 hours ago  https://photos.zillowstatic.com/p_e/IS2rl9jduo...
# 6            11 hours ago  https://photos.zillowstatic.com/p_e/ISvkz5ml3h...
# 7            13 hours ago  https://maps.googleapis.com/maps/api/streetvie...
#
#   list-card-save-content list-card-truncate
# 0         Save this home                NaN
# 1         Save this home         C's Realty
# 4         Save this home       Realty Depot
# 6         Save this home                NaN
# 7         Save this home                NaN

# %%
import json

def parse_json(s):
    result = {'Latitude': '', 'Longitude': '',  'error': ''}
    json_data = json.loads(s)
    try:
        result['Latitude'] = json_data.get('geo').get('latitude')
        result['Longitude'] = json_data.get('geo').get('longitude')
    except Exception as e:
        result['error'] = str(e)
    return(result)

# %%
series = df['json_data'].apply(parse_json)
series
# Out:
# 0      {'Latitude': 40.744062, 'Longitude': -73.83262...
# 1      {'Latitude': 40.74898, 'Longitude': -73.79658,...
# 4      {'Latitude': 40.72459, 'Longitude': -73.81841,...
# 6      {'Latitude': 40.74563, 'Longitude': -73.8293, ...
# 7      {'Latitude': 40.740659, 'Longitude': -73.85179...
#                              ...
# 634    {'Latitude': 40.74064, 'Longitude': -73.81122,...
# 635    {'Latitude': 40.72494, 'Longitude': -73.81468,...
# 636    {'Latitude': 40.72494, 'Longitude': -73.81468,...
# 637    {'Latitude': 40.74385, 'Longitude': -73.830555...
# 638    {'Latitude': 40.727693, 'Longitude': -73.79350...
# Name: json_data, Length: 573, dtype: object

# %%
output_df = pd.DataFrame(index = df.index)
output_df['Latitude'] = series.apply( lambda d: "{}".format(d['Latitude'])).astype(float)
output_df['Longitude'] = series.apply( lambda d: "{}".format(d['Longitude'])).astype(float)

# %%
output_df.head()
# Out:
#     Latitude  Longitude
# 0  40.744062 -73.832622
# 1  40.748980 -73.796580
# 4  40.724590 -73.818410
# 6  40.745630 -73.829300
# 7  40.740659 -73.851792

# %%
column_map = {'ListingType': 'list-card-type',
             'ListingPrice': 'list-card-price',
             'FloorSize': 'list-card-details 3',
             'TimeOnMarket': 'list-card-variable-text'}
for k, v in column_map.items():
    output_df[k] = df[v]

output_df.head()
# Out:
#     Latitude  Longitude         ListingType ListingPrice FloorSize  \
# 0  40.744062 -73.832622  Apartment for rent    $2,200/mo        --
# 1  40.748980 -73.796580  Apartment for rent    $1,100/mo        --
# 4  40.724590 -73.818410  Apartment for rent    $1,400/mo       350
# 6  40.745630 -73.829300  Apartment for rent    $2,300/mo     1,200
# 7  40.740659 -73.851792  Apartment for rent    $2,500/mo     3,078
#
#     TimeOnMarket
# 0  2 minutes ago
# 1    2 hours ago
# 4   10 hours ago
# 6   11 hours ago
# 7   13 hours ago

# %%
output_df.to_csv("zillow_parsed_forrent.csv", index=False)

# %% [markdown]
# # Now we have the data, let's show it on Google Map!!!

# %%
# find the average long, lat
longitude = output_df['Longitude'].astype(float).mean()
latitude = output_df['Latitude'].astype(float).mean()
print(longitude, latitude)
# Out:
# -73.82742549389197 40.732591930191965

# %%
##https://python-graph-gallery.com/288-map-background-with-folium/
tiles_choices = ["CartoDB dark_matter", "cartodb positron", "openstreetmap"]
fmap = folium.Map(location=[latitude, longitude], zoom_start=10,  tiles = "cartodb positron")
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fmap = folium.Map(location=[latitude, longitude], zoom_start=10,  tiles = "openstreetmap")
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fmap = folium.Map(location=[latitude, longitude], zoom_start=10,  tiles = "Stamen Terrain")
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Add additional column**

# %%
adf = output_df
adf['price'] = adf['ListingPrice'].apply(lambda x: x.replace('$','').replace(',','').replace('/mo', '')).astype(float)
adf['price_z_score'] = (adf['price'] - adf['price'].mean())/adf['price'].std()
adf['UsefulInfo'] = adf.apply( lambda row: "Floor Size: {} sqft; Time on Market: {}".format(row['FloorSize'], row['TimeOnMarket']), axis=1)
adf.head()
# Out:
#     Latitude  Longitude         ListingType ListingPrice FloorSize  \
# 0  40.744062 -73.832622  Apartment for rent    $2,200/mo        --
# 1  40.748980 -73.796580  Apartment for rent    $1,100/mo        --
# 4  40.724590 -73.818410  Apartment for rent    $1,400/mo       350
# 6  40.745630 -73.829300  Apartment for rent    $2,300/mo     1,200
# 7  40.740659 -73.851792  Apartment for rent    $2,500/mo     3,078
#
#     TimeOnMarket   price  price_z_score  \
# 0  2 minutes ago  2200.0      -0.215536
# 1    2 hours ago  1100.0      -1.691854
# 4   10 hours ago  1400.0      -1.289221
# 6   11 hours ago  2300.0      -0.081325
# 7   13 hours ago  2500.0       0.187096
#
#                                           UsefulInfo
# 0  Floor Size: -- sqft; Time on Market: 2 minutes...
# 1   Floor Size: -- sqft; Time on Market: 2 hours ago
# 4  Floor Size: 350 sqft; Time on Market: 10 hours...
# 6  Floor Size: 1,200 sqft; Time on Market: 11 hou...
# 7  Floor Size: 3,078 sqft; Time on Market: 13 hou...

# %%
adf['ListingType'].unique()
# Out:
# array(['Apartment for rent', 'House for rent', 'Condo for rent',
#        'Townhouse for rent', 'Co-op for rent'], dtype=object)

# %%
def set_color(listing_type):
    _map = {'Apartment for rent': 'blue', 'House for rent': 'red', 'Condo for rent': 'orange', 'Townhouse for rent': 'brown',
           'Co-op for rent': 'green'}
    return(_map[listing_type])

adf['folium_color'] = adf['ListingType'].apply(set_color)

# %%
lat_col = 'Latitude'
lon_col = 'Longitude'
popup_col = 'UsefulInfo'
tooltips_col = 'ListingType'
radius_scale = 50

fmap = folium.Map(location=[latitude, longitude], zoom_start=15,  tiles = "cartodb positron")
for i in range(adf.shape[0]):
    folium.Circle(location=[adf.iloc[i][lat_col], adf.iloc[i][lon_col]],
                  popup=adf.iloc[i][popup_col],
                  tooltiptip=adf.iloc[i][tooltips_col],
                  radius=int(adf.iloc[i]['price_z_score'] * radius_scale),
                  color=adf.iloc[i]['folium_color'],
                  fill = True,
                  fill_opacity=0.2, 
                  line_opacity=0.2
                  ).add_to(fmap)
    
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
