# %% [markdown]
# ## HomeWork 2 EDA, Data Visualization and Linear Regression Model

# %% [markdown]
# # Due on 10/2/2019 mid-night

# %% [markdown]
# ## Late Policy: Take off 50% after one day, 80% after two days

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading our MPG3 dataset

# %%
mpg = pd.read_csv("mpg3.csv")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.shape
# Out:
# (405, 9)

# %% [markdown]
# # Question 1: Check to see if there are any missing values. Fix the missing values by imputing value from the mean. After fixing missing values, you should still have 405 rows

# %%
print(mpg.isnull().any())
print(mpg.shape)
df = mpg

df['mpg'] = df['mpg'].fillna(df['mpg'].mean())
print(mpg.shape)

df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mean())
print(mpg.shape)

df['weight'] = df['weight'].fillna(df['weight'].mean())
print(mpg.shape)
# Out:
# mpg              True
# cylinders       False
# displacement    False
# horsepower       True
# weight           True
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool
# (405, 9)
# (405, 9)
# (405, 9)
# (405, 9)

# %% [markdown]
# # Question 2 : Use Boxplot to see if there are any outliers on ALL of the numerical fields (Hint you should have 402 rows now after outliers removal)

# %% [markdown]
# **Type in your code here**

# %%
sns.boxplot(x=mpg['mpg'])
print(mpg.shape)
mpg= mpg[mpg.mpg<80]
print(mpg.shape)
# Out:
# (405, 9)
# (404, 9)

# %%
sns.boxplot(x=mpg['cylinders'])
print(mpg.shape)
mpg= mpg[mpg.cylinders<15]
print(mpg.shape)
# Out:
# (404, 9)
# (403, 9)

# %%
sns.boxplot(x=mpg['displacement'])
print(mpg.shape)
# Out:
# (403, 9)

# %%
sns.boxplot(x=mpg['horsepower'])
print(mpg.shape)
# Out:
# (403, 9)

# %%
sns.boxplot(x=mpg['weight'])
print(mpg.shape)

mpg= mpg[mpg.weight<20000]
print(mpg.shape)
# Out:
# (403, 9)
# (402, 9)

# %%
sns.boxplot(x=mpg['acceleration'])
print(mpg.shape)
# Out:
# (402, 9)

# %% [markdown]
# # Question 3 : Remove any duplicates rows. Hint after removal, you should have 400 rows now

# %%
# Show number of rows before
print("Before duplicates removal: ", mpg.shape)

# Type your code here to remove duplicated rows

mpg= mpg.drop_duplicates()

# hint: Google how to remove duplicate rows in pandas dataframe and you will find the link
# https://pandas.pydata.org/pandas-docs/version/0.17/generated/pandas.DataFrame.drop_duplicates.html

# Show number of rows before
print("After duplicates removal: ", mpg.shape)
# Out:
# Before duplicates removal:  (402, 9)
# After duplicates removal:  (400, 9)

# %% [markdown]
# # Question 4: Create a pair plot

# %%
# Type your code here

# %%
print(sns.pairplot(mpg))
# Out:
# <seaborn.axisgrid.PairGrid object at 0x1a169c1e48>

# %% [markdown]
# # Question 5: Create a FacetGrid of a scatter plot of mpg vs weight for different country

# %%
g = sns.FacetGrid(mpg, col = 'origin')
g = (g.map(plt.scatter, "weight", "mpg").add_legend())

# %% [markdown]
# # Now Load the adult income dataset and do some EDA and answer the following questions based on the Adult income dataset

# %%
adult = pd.read_csv("adult.data.csv")
adult.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
adult.isnull().any()
# Out:
# age               False
# workclass         False
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation        False
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country    False
# salary            False
# dtype: bool

# %%
print(adult.shape)
adult.describe()
# Out:
# (32561, 15)
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # Question 6 : Which two martial-status is most common

# %% [markdown]
# # Answer:
# The two most common marital-status is Married-civ-spouse and Never-married

# %%
occ = adult.groupby('marital-status')
occ1 = adult[adult['marital-status']=='Never-married']
occ2 = adult[adult['marital-status']=='Married-civ-spouse']
occ3 = adult[adult['marital-status']=='Divorced']
occ4 = adult[adult['marital-status']=='Married-spouse-absent']
occ5 = adult[adult['marital-status']=='Separated']
occ6 = adult[adult['marital-status']=='Married-AF-spouse']
occ7 = adult[adult['marital-status']=='Widowed']

print(occ1.size)
print(occ2.size)
print(occ3.size)
print(occ4.size)
print(occ5.size)
print(occ6.size)
print(occ7.size)

adult['marital-status'].unique()
# Out:
# 160245
# 224640
# 66645
# 6270
# 15375
# 345
# 14895
# array(['Never-married', 'Married-civ-spouse', 'Divorced',
#        'Married-spouse-absent', 'Separated', 'Married-AF-spouse',
#        'Widowed'], dtype=object)

# %% [markdown]
# # Question 7: Plot the age distribution broken down by different martial-status using a FacetGrid

# %%
# Type your code here

# %%
#g = sns.FacetGrid(adult, col = 'marital-status')
#g = (g.map(plt.scatter, "age", "age").add_legend())

g = sns.FacetGrid(adult, col = 'marital-status')
g = g.map(plt.hist, 'age')

# %% [markdown]
# # Question 8: Create a Facet Grid for fnlwgt against age broken down by race and sex. You should have 10 sub-plots

# %%
# Type your code here
g = sns.FacetGrid(adult, row = 'sex' ,col = 'race')
g = (g.map(plt.scatter, "fnlwgt", "age").add_legend())

# %% [markdown]
# # Now Load the housing data and answer all the remaining questions based on the housing dataset

# %%
housing = pd.read_csv("USA_housing.csv")
housing.head()
# Out:
#         Income  HouseAge  NumberOfRooms  AreaNumberOfBedrooms   Population  \
# 0  79545.45857  5.682861       7.009188                  4.09  23086.80050
# 1  79248.64245  6.002900       6.730821                  3.09  40173.07217
# 2  61287.06718  5.865890       8.512727                  5.13  36882.15940
# 3  63345.24005  7.188236       5.586729                  3.26  34310.24283
# 4  59982.19723  5.040555       7.839388                  4.23  26354.10947
#
#           Price                                            Address
# 0  1.059034e+06  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  1.505891e+06  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  1.058988e+06  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3  1.260617e+06                          USS Barnett\nFPO AP 44820
# 4  6.309435e+05                         USNS Raymond\nFPO AE 09386

# %%
# a scatter plot comparing num_children and num_pets
housing.plot(kind='scatter',x='Income',y='Price',color='blue')
plt.show()

# %%
housing.plot(kind='scatter', x = "HouseAge", y = "Price", color = "blue")

# %%
housing.plot(kind='scatter', x = "NumberOfRooms", y = "Price", color = "green")

# %% [markdown]
# # Question 9: Use a pair plot or individual scatter plots, pick ONE variable that best explains house price

# %% [markdown]
# Income affects the house price the most because in the pairplot, out of all the variables the income to price graph
# appears to form more of a linear relationship/direct relation. The correlation is also the highest.

# %%
# Type your answer (ie which variable affect the Price the most)
print(housing.corr())
print(sns.pairplot(housing))
# Out:
#                         Income  HouseAge  NumberOfRooms  AreaNumberOfBedrooms  \
# Income                1.000000 -0.002007      -0.011032              0.019788
# HouseAge             -0.002007  1.000000      -0.009428              0.006149
# NumberOfRooms        -0.011032 -0.009428       1.000000              0.462695
# AreaNumberOfBedrooms  0.019788  0.006149       0.462695              1.000000
# Population           -0.016234 -0.018743       0.002040             -0.022168
# Price                 0.639734  0.452543       0.335664              0.171071
#
#                       Population     Price
# Income                 -0.016234  0.639734
# HouseAge               -0.018743  0.452543
# NumberOfRooms           0.002040  0.335664
# AreaNumberOfBedrooms   -0.022168  0.171071
# Population              1.000000  0.408556
# Price                   0.408556  1.000000
# <seaborn.axisgrid.PairGrid object at 0x1a15791cf8>

# %% [markdown]
# # Question 10:  Use that variable to build a one-variable Linear Regression model of the house price. Make sure you split the data between Training and Testing set first, Save 20% as your testing data

# %%
# Show your work here
housing.isnull().any()

Xarray = housing['Income'].values
Yarray = housing['Price'].values
X = Xarray.reshape(-1, 1)
Y = Yarray.reshape(-1, 1)

from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
print(0.8 * adult.shape[0])

print("\ntraining model")
model1 = LinearRegression()
model1.fit(X_train, Y_train)
print("intercept: ", model1.intercept_)
print("coef: ",model1.coef_)

print("\nLinear Regression Model")
Y_pred = model1.predict(X_test)
plt.scatter(X_test, Y_test,  color='gray')
plt.scatter(X_test, Y_pred, color='red', linewidth=2)
plt.show()
# Out:
# (4000, 1)
# (1000, 1)
# (4000, 1)
# (1000, 1)
# 26048.800000000003
#
# training model
# intercept:  [-224617.80110797]
# coef:  [[21.24368249]]
#
# Linear Regression Model

# %%
# Show your R-square and RMSE
from sklearn import metrics
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R-squared:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Root Mean Squared Error: 272184.4854520049
# R-squared: 0.4006059806785851

# %% [markdown]
# # Question 11: Now do a 10-fold Cross Validation of your model. Does your model pass cross validation?

# %% [markdown]
# Yes my model does pass cross validation because the r squared value is roughly the same on each training/testing set.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)
model2 = LinearRegression()
model2.fit(X_train, Y_train)
print("\ntraining model 2")
print("intercept: ",model2.intercept_)
print("coef: ",model2.coef_)

print("\nLinear Regression Model 2")
Y_pred = model1.predict(X_test)
plt.scatter(X_test, Y_test,  color='gray')
plt.scatter(X_test, Y_pred, color='red', linewidth=2)
plt.show()

print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R-squared:', metrics.r2_score(Y_test, Y_pred))
# Out:
# training model 2
# intercept:  [-198109.98814522]
# coef:  [[20.86775228]]
#
# Linear Regression Model 2
# Root Mean Squared Error: 274703.09598267876
# R-squared: 0.43883544223927684

# %%
# Show your work here

import random
rsquare = []
for i in range(10):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = random.randint(1,1000))
    model = LinearRegression()
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    rsquare.append(metrics.r2_score(Y_test, Y_pred))
    
rdf = pd.DataFrame( {'trial': range(10), 'Rsquare': rsquare})
print(rdf)
print("\nRsquared mean: ")

print(rdf['Rsquare'].mean())
# Out:
#    trial   Rsquare
# 0      0  0.453569
# 1      1  0.395777
# 2      2  0.425777
# 3      3  0.345835
# 4      4  0.462189
# 5      5  0.395542
# 6      6  0.381474
# 7      7  0.394133
# 8      8  0.437695
# 9      9  0.404864
#
# Rsquared mean:
# 0.40968544960836856

# %% [markdown]
# # Question 12: Now pick ONE more variable in addition to the variable you choose from Question 9 and build a two-variables Linear Regression model of the house price. Make sure you split the data into training and testing set first

# %%
# Show your work here

# %%
Xarray = housing[['Income','HouseAge']].values
Yarray = housing['Price'].values
X = Xarray.reshape(-1, 2)
Y = Yarray.reshape(-1, 1)

from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
print(0.8 * adult.shape[0])

print("\ntraining model")
model1 = LinearRegression()
model1.fit(X_train, Y_train)
print("intercept: ", model1.intercept_)
print("coef: ",model1.coef_)

print("\nLinear Regression Model")
Y_pred = model1.predict(X_test)

plt.scatter(Y_test, Y_pred, color='red', linewidth=2)
plt.show()
from sklearn import metrics
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R-squared:', metrics.r2_score(Y_test, Y_pred))
# Out:
# (4000, 2)
# (1000, 2)
# (4000, 1)
# (1000, 1)
# 26048.800000000003
#
# training model
# intercept:  [-1181216.65021219]
# coef:  [[2.12204386e+01 1.60427782e+05]]
#
# Linear Regression Model
# Root Mean Squared Error: 219231.4703428264
# R-squared: 0.6111416177920193

# %% [markdown]
# # Question 13: Do a 10-fold Cross Validation of your two-variable model. Does your model pass cross validation?

# %% [markdown]
# Yes my model passes cross validation because the rsquared on the first model was 0.611 and when I performed the 10-fold cross validation, ech one resulted with roughly the same rsquared.

# %%
rsquare = []
for i in range(10):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = random.randint(1,1000))
    model = LinearRegression()
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    rsquare.append(metrics.r2_score(Y_test, Y_pred))
    print('Trial {}, R-squared: {},  Slope: {}, Intercept: {},  '.format(i, metrics.r2_score(Y_test, Y_pred), \
                                                                      model.coef_, model.intercept_))

    
rdf = pd.DataFrame( {'trial': range(10), 'Rsquare': rsquare})
rdf.plot.bar(x='trial', y='Rsquare')
# Out:
# Trial 0, R-squared: 0.6366477390704578,  Slope: [[2.12248104e+01 1.57531238e+05]], Intercept: [-1167469.37670273],
# Trial 1, R-squared: 0.5988889799623701,  Slope: [[2.14894394e+01 1.61972393e+05]], Intercept: [-1210594.60301018],
# Trial 2, R-squared: 0.5921191031586577,  Slope: [[2.13801739e+01 1.63685431e+05]], Intercept: [-1208036.08645233],
# Trial 3, R-squared: 0.6127777481950498,  Slope: [[2.12447064e+01 1.61351560e+05]], Intercept: [-1186338.92606872],
# Trial 4, R-squared: 0.5947082528053682,  Slope: [[2.12130611e+01 1.62932874e+05]], Intercept: [-1198799.01148505],
# Trial 5, R-squared: 0.6270252475618365,  Slope: [[2.12728770e+01 1.62845638e+05]], Intercept: [-1202435.45857111],
# Trial 6, R-squared: 0.6007297309253069,  Slope: [[2.11196396e+01 1.63667012e+05]], Intercept: [-1195241.363408],
# Trial 7, R-squared: 0.5970511467620842,  Slope: [[2.14382725e+01 1.62197194e+05]], Intercept: [-1205162.1527658],
# Trial 8, R-squared: 0.6266230267564934,  Slope: [[2.1139538e+01 1.6029830e+05]], Intercept: [-1177128.27702009],
# Trial 9, R-squared: 0.6305510391112743,  Slope: [[2.11855190e+01 1.60726764e+05]], Intercept: [-1181208.0594495],
